# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sb

# %%
df = pd.read_csv("Dataset-Pure/train.csv/train.csv", sep='|', index_col='id')

# %%
df
# Out:
#                                             job_title         location  \
# id
# 1      Facility Maintenance & Smart Warehouse Manager          Bandung
# 2                         Procurement Department Head     Jakarta Raya
# 3                                         SALES ADMIN    Jakarta Barat
# 4        City Operation Lead Shopee Express (Cirebon)          Cirebon
# 5                                Japanese Interpreter           Bekasi
# ...                                               ...              ...
# 31742                   Deputy Head of Internal Audit  Jakarta Selatan
# 31743                    Foreman Warehouse & Logistic         Surabaya
# 31744                                  System Analyst  Jakarta Selatan
# 31745        Developer Security Operation (DevSecOps)    Jakarta Pusat
# 31746                             Maintenance Officer           Manado
#
#       salary_currency                              career_level  \
# id
# 1                 IDR                   Manajer/Asisten Manajer
# 2                 IDR                   Manajer/Asisten Manajer
# 3                 IDR                    Supervisor/Koordinator
# 4                 IDR                    Supervisor/Koordinator
# 5                 IDR  Pegawai (non-manajemen & non-supervisor)
# ...               ...                                       ...
# 31742             IDR  Pegawai (non-manajemen & non-supervisor)
# 31743             IDR                    Supervisor/Koordinator
# 31744             IDR  Pegawai (non-manajemen & non-supervisor)
# 31745             IDR  Pegawai (non-manajemen & non-supervisor)
# 31746             IDR  Pegawai (non-manajemen & non-supervisor)
#
#       experience_level                                    education_level  \
# id
# 1              5 tahun  Sertifikat Professional, D3 (Diploma), D4 (Dip...
# 2              5 tahun  Sarjana (S1), Diploma Pascasarjana, Gelar Prof...
# 3              4 tahun                                       Sarjana (S1)
# 4              5 tahun  Sarjana (S1), Diploma Pascasarjana, Gelar Prof...
# 5              2 tahun  Sertifikat Professional, D3 (Diploma), D4 (Dip...
# ...                ...                                                ...
# 31742          5 tahun  Sarjana (S1), Diploma Pascasarjana, Gelar Prof...
# 31743          3 tahun                                       Sarjana (S1)
# 31744          3 tahun                                       Sarjana (S1)
# 31745          2 tahun                                       Sarjana (S1)
# 31746          3 tahun  SMA, SMU/SMK/STM, Sertifikat Professional, D3 ...
#
#       employment_type                                       job_function  \
# id
# 1         Penuh Waktu                            Manufaktur,Pemeliharaan
# 2         Penuh Waktu            Manufaktur,Pembelian/Manajemen Material
# 3         Penuh Waktu              Penjualan / Pemasaran,Penjualan Ritel
# 4         Penuh Waktu                  Pelayanan,Logistik/Rantai Pasokan
# 5         Penuh Waktu                            Lainnya,Jurnalis/Editor
# ...               ...                                                ...
# 31742     Penuh Waktu   Akuntansi / Keuangan,Perbankan / Jasa Finansial
# 31743     Penuh Waktu            Manufaktur,Pembelian/Manajemen Material
# 31744     Penuh Waktu    Komputer/Teknologi Informasi,IT-Perangkat Lunak
# 31745     Penuh Waktu  Komputer/Teknologi Informasi,IT-Admin Jaringan...
# 31746     Penuh Waktu  Bangunan/Konstruksi,Teknik Sipil/Konstruksi Ba...
#
#                                             job_benefits company_process_time  \
# id
# 1                                                    NaN                  NaN
# 2                                                    NaN              25 days
# 3      Waktu regular, Senin - Jumat;Bisnis (contoh: K...              30 days
# 4      Tip;Waktu regular, Senin - Jumat;Kasual (conto...              21 days
# 5                                                    NaN              23 days
# ...                                                  ...                  ...
# 31742  Asuransi Gigi;Asuransi kesehatan;Parkir;Pengli...              29 days
# 31743  Tip;Asuransi kesehatan;Parkir;Bisnis (contoh: ...              26 days
# 31744  Tip;Asuransi kesehatan;Waktu regular, Senin - ...              11 days
# 31745  Tip;Asuransi kesehatan;Parkir;Waktu regular, S...              18 days
# 31746  Asuransi kesehatan;Waktu regular, Senin - Juma...              29 days
#
#               company_size                                   company_industry  \
# id
# 1                      NaN                                                NaN
# 2         51 - 200 pekerja                            Manajemen/Konsulting HR
# 3         51 - 200 pekerja                                      Umum & Grosir
# 4      2001 - 5000 pekerja                                 Retail/Merchandise
# 5        201 - 500 pekerja                            Manajemen/Konsulting HR
# ...                    ...                                                ...
# 31742    201 - 500 pekerja                       Perbankan/Pelayanan Keuangan
# 31743  1001 - 2000 pekerja                                Manufaktur/Produksi
# 31744     51 - 200 pekerja  Konsultasi (IT, Ilmu Pengetahuan, Teknis & Tek...
# 31745    201 - 500 pekerja      Komputer/Teknik Informatika (Perangkat Lunak)
# 31746  2001 - 5000 pekerja                                 Retail/Merchandise
#
#                                          job_description     salary
# id
# 1      Deskripsi PekerjaanRequirements :D3/SI from re...        NaN
# 2      Job Role: 1. Responsible for material availabi...        NaN
# 3      Internal Sales & AdminJob Description :We are ...        NaN
# 4      Job Description:Responsible for HSE implementa...        NaN
# 5      Overview: Our clients is manufacture for autom...        NaN
# ...                                                  ...        ...
# 31742  Key Responsibilities :Conduct audits to review...        NaN
# 31743  KRITERIA dan SYARATS1 Tehnik Industri, Statisi...        NaN
# 31744  Tanggung jawab:Mengumpulkan, menganalisa kebut...        NaN
# 31745  1.      Protect All Aspects of Your Source Cod...  7500000.0
# 31746  Your responsibilities:The job of an H&M Mainte...        NaN
#
# [31746 rows x 14 columns]

# %%
df.head()
# Out:
#                                          job_title       location  \
# id
# 1   Facility Maintenance & Smart Warehouse Manager        Bandung
# 2                      Procurement Department Head   Jakarta Raya
# 3                                      SALES ADMIN  Jakarta Barat
# 4     City Operation Lead Shopee Express (Cirebon)        Cirebon
# 5                             Japanese Interpreter         Bekasi
#
#    salary_currency                              career_level experience_level  \
# id
# 1              IDR                   Manajer/Asisten Manajer          5 tahun
# 2              IDR                   Manajer/Asisten Manajer          5 tahun
# 3              IDR                    Supervisor/Koordinator          4 tahun
# 4              IDR                    Supervisor/Koordinator          5 tahun
# 5              IDR  Pegawai (non-manajemen & non-supervisor)          2 tahun
#
#                                       education_level employment_type  \
# id
# 1   Sertifikat Professional, D3 (Diploma), D4 (Dip...     Penuh Waktu
# 2   Sarjana (S1), Diploma Pascasarjana, Gelar Prof...     Penuh Waktu
# 3                                        Sarjana (S1)     Penuh Waktu
# 4   Sarjana (S1), Diploma Pascasarjana, Gelar Prof...     Penuh Waktu
# 5   Sertifikat Professional, D3 (Diploma), D4 (Dip...     Penuh Waktu
#
#                                job_function  \
# id
# 1                   Manufaktur,Pemeliharaan
# 2   Manufaktur,Pembelian/Manajemen Material
# 3     Penjualan / Pemasaran,Penjualan Ritel
# 4         Pelayanan,Logistik/Rantai Pasokan
# 5                   Lainnya,Jurnalis/Editor
#
#                                          job_benefits company_process_time  \
# id
# 1                                                 NaN                  NaN
# 2                                                 NaN              25 days
# 3   Waktu regular, Senin - Jumat;Bisnis (contoh: K...              30 days
# 4   Tip;Waktu regular, Senin - Jumat;Kasual (conto...              21 days
# 5                                                 NaN              23 days
#
#            company_size         company_industry  \
# id
# 1                   NaN                      NaN
# 2      51 - 200 pekerja  Manajemen/Konsulting HR
# 3      51 - 200 pekerja            Umum & Grosir
# 4   2001 - 5000 pekerja       Retail/Merchandise
# 5     201 - 500 pekerja  Manajemen/Konsulting HR
#
#                                       job_description  salary
# id
# 1   Deskripsi PekerjaanRequirements :D3/SI from re...     NaN
# 2   Job Role: 1. Responsible for material availabi...     NaN
# 3   Internal Sales & AdminJob Description :We are ...     NaN
# 4   Job Description:Responsible for HSE implementa...     NaN
# 5   Overview: Our clients is manufacture for autom...     NaN

# %%
df.tail()
# Out:
#                                       job_title         location  \
# id
# 31742             Deputy Head of Internal Audit  Jakarta Selatan
# 31743              Foreman Warehouse & Logistic         Surabaya
# 31744                            System Analyst  Jakarta Selatan
# 31745  Developer Security Operation (DevSecOps)    Jakarta Pusat
# 31746                       Maintenance Officer           Manado
#
#       salary_currency                              career_level  \
# id
# 31742             IDR  Pegawai (non-manajemen & non-supervisor)
# 31743             IDR                    Supervisor/Koordinator
# 31744             IDR  Pegawai (non-manajemen & non-supervisor)
# 31745             IDR  Pegawai (non-manajemen & non-supervisor)
# 31746             IDR  Pegawai (non-manajemen & non-supervisor)
#
#       experience_level                                    education_level  \
# id
# 31742          5 tahun  Sarjana (S1), Diploma Pascasarjana, Gelar Prof...
# 31743          3 tahun                                       Sarjana (S1)
# 31744          3 tahun                                       Sarjana (S1)
# 31745          2 tahun                                       Sarjana (S1)
# 31746          3 tahun  SMA, SMU/SMK/STM, Sertifikat Professional, D3 ...
#
#       employment_type                                       job_function  \
# id
# 31742     Penuh Waktu   Akuntansi / Keuangan,Perbankan / Jasa Finansial
# 31743     Penuh Waktu            Manufaktur,Pembelian/Manajemen Material
# 31744     Penuh Waktu    Komputer/Teknologi Informasi,IT-Perangkat Lunak
# 31745     Penuh Waktu  Komputer/Teknologi Informasi,IT-Admin Jaringan...
# 31746     Penuh Waktu  Bangunan/Konstruksi,Teknik Sipil/Konstruksi Ba...
#
#                                             job_benefits company_process_time  \
# id
# 31742  Asuransi Gigi;Asuransi kesehatan;Parkir;Pengli...              29 days
# 31743  Tip;Asuransi kesehatan;Parkir;Bisnis (contoh: ...              26 days
# 31744  Tip;Asuransi kesehatan;Waktu regular, Senin - ...              11 days
# 31745  Tip;Asuransi kesehatan;Parkir;Waktu regular, S...              18 days
# 31746  Asuransi kesehatan;Waktu regular, Senin - Juma...              29 days
#
#               company_size                                   company_industry  \
# id
# 31742    201 - 500 pekerja                       Perbankan/Pelayanan Keuangan
# 31743  1001 - 2000 pekerja                                Manufaktur/Produksi
# 31744     51 - 200 pekerja  Konsultasi (IT, Ilmu Pengetahuan, Teknis & Tek...
# 31745    201 - 500 pekerja      Komputer/Teknik Informatika (Perangkat Lunak)
# 31746  2001 - 5000 pekerja                                 Retail/Merchandise
#
#                                          job_description     salary
# id
# 31742  Key Responsibilities :Conduct audits to review...        NaN
# 31743  KRITERIA dan SYARATS1 Tehnik Industri, Statisi...        NaN
# 31744  Tanggung jawab:Mengumpulkan, menganalisa kebut...        NaN
# 31745  1.      Protect All Aspects of Your Source Cod...  7500000.0
# 31746  Your responsibilities:The job of an H&M Mainte...        NaN

# %%
df.describe()
# Out:
#              salary
# count  6.352000e+03
# mean   7.102330e+06
# std    5.935192e+06
# min    1.000000e+01
# 25%    4.250000e+06
# 50%    5.500000e+06
# 75%    8.000000e+06
# max    1.150000e+08

# %%
df.describe(include='O')
# Out:
#               job_title      location salary_currency  \
# count             31746         31746           31742
# unique            19260           199               2
# top     Sales Executive  Jakarta Raya             IDR
# freq                273          7551           31731
#
#                                     career_level experience_level  \
# count                                      31746            27454
# unique                                         6               20
# top     Pegawai (non-manajemen & non-supervisor)          1 tahun
# freq                                       17566             9766
#
#        education_level employment_type                           job_function  \
# count            31746           30402                                  31746
# unique              21               9                                     68
# top       Sarjana (S1)     Penuh Waktu  Penjualan / Pemasaran,Penjualan Ritel
# freq             10340           25940                                   3428
#
#                                              job_benefits  \
# count                                               25079
# unique                                               2978
# top     Asuransi kesehatan;Waktu regular, Senin - Juma...
# freq                                                 2000
#
#        company_process_time      company_size     company_industry  \
# count                 22602             26583                30232
# unique                   30                 7                   58
# top                 29 days  51 - 200 pekerja  Manufaktur/Produksi
# freq                   4231              6931                 2775
#
#                                           job_description
# count                                               31745
# unique                                              26981
# top     Lowongan ini akan mengarahkan anda langsung ke...
# freq                                                   60

# %%
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# salary_currency             4
# experience_level         4292
# employment_type          1344
# job_benefits             6667
# company_process_time     9144
# company_size             5163
# company_industry         1514
# job_description             1
# salary                  25394
# dtype: int64
