# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sb
# Out:
# C:\Users\KEY\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv("Dataset-Pure/train.csv/train.csv", sep='|', index_col='id')

# %%
df
# Out:
#                                             job_title         location  \
# id
# 1      Facility Maintenance & Smart Warehouse Manager          Bandung
# 2                         Procurement Department Head     Jakarta Raya
# 3                                         SALES ADMIN    Jakarta Barat
# 4        City Operation Lead Shopee Express (Cirebon)          Cirebon
# 5                                Japanese Interpreter           Bekasi
# ...                                               ...              ...
# 31742                   Deputy Head of Internal Audit  Jakarta Selatan
# 31743                    Foreman Warehouse & Logistic         Surabaya
# 31744                                  System Analyst  Jakarta Selatan
# 31745        Developer Security Operation (DevSecOps)    Jakarta Pusat
# 31746                             Maintenance Officer           Manado
#
#       salary_currency                              career_level  \
# id
# ...

# %%
df.head()
# Out:
#                                          job_title       location  \
# id
# 1   Facility Maintenance & Smart Warehouse Manager        Bandung
# 2                      Procurement Department Head   Jakarta Raya
# 3                                      SALES ADMIN  Jakarta Barat
# 4     City Operation Lead Shopee Express (Cirebon)        Cirebon
# 5                             Japanese Interpreter         Bekasi
#
#    salary_currency                              career_level experience_level  \
# id
# 1              IDR                   Manajer/Asisten Manajer          5 tahun
# 2              IDR                   Manajer/Asisten Manajer          5 tahun
# 3              IDR                    Supervisor/Koordinator          4 tahun
# 4              IDR                    Supervisor/Koordinator          5 tahun
# 5              IDR  Pegawai (non-manajemen & non-supervisor)          2 tahun
#
#                                       education_level employment_type  \
# id
# ...

# %%
df.tail()
# Out:
#                                       job_title         location  \
# id
# 31742             Deputy Head of Internal Audit  Jakarta Selatan
# 31743              Foreman Warehouse & Logistic         Surabaya
# 31744                            System Analyst  Jakarta Selatan
# 31745  Developer Security Operation (DevSecOps)    Jakarta Pusat
# 31746                       Maintenance Officer           Manado
#
#       salary_currency                              career_level  \
# id
# 31742             IDR  Pegawai (non-manajemen & non-supervisor)
# 31743             IDR                    Supervisor/Koordinator
# 31744             IDR  Pegawai (non-manajemen & non-supervisor)
# 31745             IDR  Pegawai (non-manajemen & non-supervisor)
# 31746             IDR  Pegawai (non-manajemen & non-supervisor)
#
#       experience_level                                    education_level  \
# id
# 31742          5 tahun  Sarjana (S1), Diploma Pascasarjana, Gelar Prof...
# ...

# %%
df.describe()
# Out:
#              salary
# count  6.352000e+03
# mean   7.102330e+06
# std    5.935192e+06
# min    1.000000e+01
# 25%    4.250000e+06
# 50%    5.500000e+06
# 75%    8.000000e+06
# max    1.150000e+08

# %%
df.describe(include='O')
# Out:
#               job_title      location salary_currency  \
# count             31746         31746           31742
# unique            19260           199               2
# top     Sales Executive  Jakarta Raya             IDR
# freq                273          7551           31731
#
#                                     career_level experience_level  \
# count                                      31746            27454
# unique                                         6               20
# top     Pegawai (non-manajemen & non-supervisor)          1 tahun
# freq                                       17566             9766
#
#        education_level employment_type                           job_function  \
# count            31746           30402                                  31746
# unique              21               9                                     68
# top       Sarjana (S1)     Penuh Waktu  Penjualan / Pemasaran,Penjualan Ritel
# ...

# %%
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# salary_currency             4
# experience_level         4292
# employment_type          1344
# job_benefits             6667
# company_process_time     9144
# company_size             5163
# company_industry         1514
# job_description             1
# salary                  25394
# dtype: int64

# %%
df_fil = df.dropna(axis=0, subset=['salary'])

# %%
df_fil
# Out:
#                                           job_title       location  \
# id
# 6                                     KEPALA PABRIK     Balikpapan
# 10                                   Tax Supervisor         Banten
# 19                                 Accounting Staff  Jakarta Pusat
# 23                          Senior Staff Purchasing       Surabaya
# 27        MARKETING COMMUNICATION & CHANNEL MANAGER  Jakarta Pusat
# ...                                             ...            ...
# 31720                               Sales - Bandung        Bandung
# 31721                                   CREW OUTLET         Bekasi
# 31730                  Flutter Developer Programmer           Aceh
# 31733  Area Business Development Associate - Madiun         Madiun
# 31745      Developer Security Operation (DevSecOps)  Jakarta Pusat
#
#       salary_currency                              career_level  \
# id
# 6                 IDR                    Supervisor/Koordinator
# ...

# %%
df_fil.describe()
# Out:
#              salary
# count  6.352000e+03
# mean   7.102330e+06
# std    5.935192e+06
# min    1.000000e+01
# 25%    4.250000e+06
# 50%    5.500000e+06
# 75%    8.000000e+06
# max    1.150000e+08

# %%
df_fil.describe(include = 'O')
# Out:
#               job_title      location salary_currency  \
# count              6352          6352            6352
# unique             4316           164               2
# top     Sales Executive  Jakarta Raya             IDR
# freq                111          1223            6350
#
#                                     career_level experience_level  \
# count                                       6352             5819
# unique                                         5               14
# top     Pegawai (non-manajemen & non-supervisor)          1 tahun
# freq                                        3913             2095
#
#        education_level employment_type                           job_function  \
# count             6352            6352                                   6352
# unique              18               8                                     67
# top       Sarjana (S1)     Penuh Waktu  Penjualan / Pemasaran,Penjualan Ritel
# ...

# %%
df_fil.columns
# Out:
# Index(['job_title', 'location', 'salary_currency', 'career_level',
#        'experience_level', 'education_level', 'employment_type',
#        'job_function', 'job_benefits', 'company_process_time', 'company_size',
#        'company_industry', 'job_description', 'salary'],
#       dtype='object')

# %%
df_fil.shape
# Out:
# (6352, 14)

# %%
s = (df_fil.dtypes == 'object')
object_cols = list(s[s].index)
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()

df_fil[object_cols] = ordinal_encoder.fit_transform(df_fil[object_cols])
# Out:
# C:\Users\KEY\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\KEY\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df_fil
# Out:
#        job_title  location  salary_currency  career_level  experience_level  \
# id
# 6         1950.0       4.0              0.0           4.0               NaN
# 10        4063.0      13.0              0.0           4.0               8.0
# 19         179.0      48.0              0.0           3.0               0.0
# 23        3627.0     148.0              0.0           3.0               6.0
# 27        2115.0      48.0              0.0           2.0               6.0
# ...          ...       ...              ...           ...               ...
# 31720     3219.0       6.0              0.0           3.0               0.0
# 31721      691.0      18.0              0.0           3.0               NaN
# 31730     1387.0       0.0              0.0           3.0              10.0
# 31733      370.0      86.0              0.0           4.0               0.0
# 31745      995.0      48.0              0.0           3.0               6.0
#
# ...

# %%
mp.pyplot.scatter(x=df_fil["location"],y=df_fil["salary"])

# %%
mp.pyplot.scatter(x=df_fil["career_level"],y=df_fil["salary"])

# %%
missing_val_count_by_column = (df_fil.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# experience_level         533
# job_benefits            1533
# company_process_time    2148
# company_size             944
# company_industry         192
# dtype: int64

# %%
mp.pyplot.scatter(x=df_fil["job_benefits"],y=df_fil["salary"])

# %%
df_fil.fillna(0,inplace=True)
# Out:
# C:\Users\KEY\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
missing_val_count_by_column = (df_fil.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# Series([], dtype: int64)

# %%
mp.pyplot.scatter(x=df_fil["company_process_time"],y=df_fil["salary"])

# %%
mp.pyplot.scatter(x=df_fil["company_size"],y=df_fil["salary"])

# %%
mp.pyplot.scatter(x=df_fil["company_industry"],y=df_fil["salary"])

# %%
df.shape
# Out:
# (31746, 14)

# %%
df_fil.describe()
# Out:
#          job_title     location  salary_currency  career_level  \
# count  6352.000000  6352.000000      6352.000000   6352.000000
# mean   2160.875157    64.779440         0.000315      2.840680
# std    1257.632133    44.942574         0.017743      0.846489
# min       0.000000     0.000000         0.000000      0.000000
# 25%    1042.750000    47.000000         0.000000      3.000000
# 50%    2190.500000    49.000000         0.000000      3.000000
# 75%    3281.000000    89.000000         0.000000      3.000000
# max    4315.000000   163.000000         1.000000      4.000000
#
#        experience_level  education_level  employment_type  job_function  \
# count       6352.000000      6352.000000      6352.000000   6352.000000
# mean           4.321474        10.612720         2.609099     29.273772
# std            3.898684         4.320116         1.039330     18.655378
# min            0.000000         0.000000         0.000000      0.000000
# ...
