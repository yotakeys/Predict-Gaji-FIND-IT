# %%
import pandas as pd

# %%
df = pd.read_csv("dataset-pure/predict-case.csv/predict-case.csv", sep='|', index_col = "id")

# %%
df
# Out:
#                                                job_title         location  \
# id
# 31747                                          Sous Chef           Lombok
# 31748  Bancassurance Officer (Area: Bali, Sulawesi Ut...             Palu
# 31749                                    Marketing Staff    Jakarta Utara
# 31750                           Section Head Commercials     Jakarta Raya
# 31751                                  Social Media HEAD             Aceh
# ...                                                  ...              ...
# 34742                                   Staff Accounting           Bekasi
# 34743                                 Frontend Developer    Jakarta Pusat
# 34744                                    Account Manager  Jakarta Selatan
# 34745                                              Sales        Palembang
# 34746  Credit Marketing Officer (CMO) - Tangerang & C...        Tangerang
#
#       salary_currency                                       career_level  \
# ...

# %%
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# experience_level         249
# job_benefits             749
# company_process_time    1047
# company_size             480
# company_industry         100
# dtype: int64

# %%
df.shape
# Out:
# (3000, 13)
